# %% [markdown]
# #Prepreocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv('/content/drive/MyDrive/AI Research/data/Sleep_Quality_and_Pattern.csv')

# %%
dataset.head()
# Out:
#          Timestamp                       Name What is your age?  \
# 0  8/13/2023 21:25               Mirza Riyad                NaN
# 1  8/13/2023 21:25  Md.Zahidul Islam Talukder               NaN
# 2  8/13/2023 21:26           Abdullah al Rafi             22-25
# 3  8/13/2023 21:41           Abdullah Al Kafi             22-25
# 4  8/13/2023 21:44          Aunirudra Dey Anu             22-25
#
#   What is your gender? How many meals do you have per day on average?  \
# 0                 Male                                    More than 4
# 1                 Male                                              2
# 2                 Male                                              4
# 3                 Male                                              2
# 4                 Male                                              2
#
#   Do you avoid screens before bed?  \
# 0    Yes, for 30 minutes to 1 hour
# 1                               No
# 2                               No
# ...

# %%
# Assuming 'pdf' is your data frame with the original column names
# Replace 'df' with your actual DataFrame name

new_column_names = {
    'What is your age?': 'Age',
    'What is your gender?': 'Gender',
    'How many meals do you have per day on average?': 'Number_Of_Meal',
    'Do you avoid screens before bed?': 'Avoidance_Screen',
    'Do you have any ongoing physical health conditions?': 'Health_Condition',
    'Do you use a blue light filter on your devices during the evening?': 'Blue_Light_Filter',
    'In which direction do you usually sleep?': 'Sleeping_Direction',
    'Do you take naps during the day?': 'Naps_During_The_Day',
    'How often do you engage in physical exercise during the week?': 'Physical_Exercise',
    'Do you consume caffeinated or sugary beverages during the evening?': 'Evening_Caffeine_Or_Sugar',
    'Do you smoke or consume alcoholic beverages?': 'Smoke_Or_Alcohol',
    'What time do you typically go to bed on a regular night?': 'Go_To_Bed_Time',
    'What time do you usually wake up in the morning?': 'Wake_Up_Time',
    'Is your bedroom dark, quiet, and conducive to sleep?': 'Dark_And_Quiet_Bedroom',
    'How would you rate your stress levels?': 'Stress_Level',
    'Do you use sleep tracking devices or apps?': 'Sleep_Traking_Device',
    'Do you have a regular bedtime routine?': 'Regular_Bedtime_Routine',
    'Is your sleep environment affected by external noise?': 'Affect_Of_External_Noice',
    'How much time do you spend in natural daylight during the day?': 'Spend_Time_In_Daylight',
    'Are you satisfied with your sleep?': 'Satisfaction',

}

# Rename the columns
dataset.rename(columns=new_column_names, inplace=True)

# Now your DataFrame 'df' will have the updated column names
dataset.head()
# Out:
#          Timestamp                       Name    Age Gender Number_Of_Meal  \
# 0  8/13/2023 21:25               Mirza Riyad     NaN   Male    More than 4
# 1  8/13/2023 21:25  Md.Zahidul Islam Talukder    NaN   Male              2
# 2  8/13/2023 21:26           Abdullah al Rafi  22-25   Male              4
# 3  8/13/2023 21:41           Abdullah Al Kafi  22-25   Male              2
# 4  8/13/2023 21:44          Aunirudra Dey Anu  22-25   Male              2
#
#                 Avoidance_Screen Health_Condition Blue_Light_Filter  \
# 0  Yes, for 30 minutes to 1 hour               No                No
# 1                             No               No                No
# 2                             No               No               Yes
# 3  Yes, for 30 minutes to 1 hour              Yes                No
# 4                             No               No               Yes
#
#   Sleeping_Direction Naps_During_The_Day  ... Smoke_Or_Alcohol Go_To_Bed_Time  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Timestamp                    0
# Name                         0
# Age                          2
# Gender                       0
# Number_Of_Meal               4
# Avoidance_Screen             1
# Health_Condition             0
# Blue_Light_Filter            0
# Sleeping_Direction           0
# Naps_During_The_Day          0
# Physical_Exercise            0
# Evening_Caffeine_Or_Sugar    0
# Smoke_Or_Alcohol             2
# Go_To_Bed_Time               0
# Wake_Up_Time                 0
# Dark_And_Quiet_Bedroom       0
# Stress_Level                 2
# Sleep_Traking_Device         0
# Regular_Bedtime_Routine      0
# Affect_Of_External_Noice     0
# Spend_Time_In_Daylight       0
# Satisfaction                 0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
import math
modeTestScore1=(dataset['Age'].mode()[0])
modeTestScore2=(dataset['Number_Of_Meal'].mode()[0])
modeTestScore3=(dataset['Avoidance_Screen'].mode()[0])
modeTestScore4=(dataset['Smoke_Or_Alcohol'].mode()[0])
modeTestScore5=(dataset['Stress_Level'].mode()[0])



dataset['Age']=dataset['Age'].fillna(modeTestScore1)
dataset['Number_Of_Meal']=dataset['Number_Of_Meal'].fillna(modeTestScore2)
dataset['Avoidance_Screen']=dataset['Avoidance_Screen'].fillna(modeTestScore3)
dataset['Smoke_Or_Alcohol']=dataset['Smoke_Or_Alcohol'].fillna(modeTestScore4)
dataset['Stress_Level']=dataset['Stress_Level'].fillna(modeTestScore5)

# %%
dataset.isnull().sum()
# Out:
# Timestamp                    0
# Name                         0
# Age                          0
# Gender                       0
# Number_Of_Meal               0
# Avoidance_Screen             0
# Health_Condition             0
# Blue_Light_Filter            0
# Sleeping_Direction           0
# Naps_During_The_Day          0
# Physical_Exercise            0
# Evening_Caffeine_Or_Sugar    0
# Smoke_Or_Alcohol             0
# Go_To_Bed_Time               0
# Wake_Up_Time                 0
# Dark_And_Quiet_Bedroom       0
# Stress_Level                 0
# Sleep_Traking_Device         0
# Regular_Bedtime_Routine      0
# Affect_Of_External_Noice     0
# Spend_Time_In_Daylight       0
# Satisfaction                 0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.isnull().sum()
# Out:
# Timestamp                    0
# Name                         0
# Age                          0
# Gender                       0
# Number_Of_Meal               0
# Avoidance_Screen             0
# Health_Condition             0
# Blue_Light_Filter            0
# Sleeping_Direction           0
# Naps_During_The_Day          0
# Physical_Exercise            0
# Evening_Caffeine_Or_Sugar    0
# Smoke_Or_Alcohol             0
# Go_To_Bed_Time               0
# Wake_Up_Time                 0
# Dark_And_Quiet_Bedroom       0
# Stress_Level                 0
# Sleep_Traking_Device         0
# Regular_Bedtime_Routine      0
# Affect_Of_External_Noice     0
# Spend_Time_In_Daylight       0
# Satisfaction                 0
# dtype: int64

# %%
dataset = dataset.drop(columns=['Timestamp'])
dataset = dataset.drop(columns=['Name'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

one=le.fit_transform(dataset['Age'])
two=le.fit_transform(dataset['Gender'])
three=le.fit_transform(dataset['Number_Of_Meal'])
four=le.fit_transform(dataset['Health_Condition'])
five=le.fit_transform(dataset['Avoidance_Screen'])
six=le.fit_transform(dataset['Blue_Light_Filter'])
seven=le.fit_transform(dataset['Sleeping_Direction'])
eight=le.fit_transform(dataset['Naps_During_The_Day'])
nine=le.fit_transform(dataset['Physical_Exercise'])
ten=le.fit_transform(dataset['Evening_Caffeine_Or_Sugar'])
eleven=le.fit_transform(dataset['Smoke_Or_Alcohol'])
twelve=le.fit_transform(dataset['Go_To_Bed_Time'])
thirteen=le.fit_transform(dataset['Wake_Up_Time'])
forteen=le.fit_transform(dataset['Dark_And_Quiet_Bedroom'])
fifteen=le.fit_transform(dataset['Stress_Level'])
sixteen=le.fit_transform(dataset['Sleep_Traking_Device'])
seventeen=le.fit_transform(dataset['Regular_Bedtime_Routine'])
eighteen=le.fit_transform(dataset['Affect_Of_External_Noice'])
nineteen=le.fit_transform(dataset['Spend_Time_In_Daylight'])
twenty=le.fit_transform(dataset['Satisfaction'])



dataset['Age']=one
dataset['Gender']=two
dataset['Number_Of_Meal']=three
dataset['Health_Condition']=four
dataset['Avoidance_Screen']=five
dataset['Blue_Light_Filter']=six
dataset['Sleeping_Direction']=seven
dataset['Naps_During_The_Day']=eight
dataset['Physical_Exercise']=nine
dataset['Evening_Caffeine_Or_Sugar']=ten
dataset['Smoke_Or_Alcohol']=eleven
dataset['Go_To_Bed_Time']=twelve
dataset['Wake_Up_Time']=thirteen
dataset['Dark_And_Quiet_Bedroom']=forteen
dataset['Stress_Level']=fifteen
dataset['Sleep_Traking_Device']=sixteen
dataset['Regular_Bedtime_Routine']=seventeen
dataset['Affect_Of_External_Noice']=eighteen
dataset['Spend_Time_In_Daylight']=nineteen
dataset['Satisfaction']=nineteen

# %%
dataset.head()
# Out:
#    Age  Gender  Number_Of_Meal  Avoidance_Screen  Health_Condition  \
# 0    1       1               3                 1                 0
# 1    1       1               0                 0                 0
# 2    1       1               2                 0                 0
# 3    1       1               0                 1                 1
# 4    1       1               0                 0                 0
#
#    Blue_Light_Filter  Sleeping_Direction  Naps_During_The_Day  \
# 0                  0                   3                    2
# 1                  0                   1                    0
# 2                  1                   1                    1
# 3                  0                   3                    1
# 4                  1                   1                    0
#
#    Physical_Exercise  Evening_Caffeine_Or_Sugar  Smoke_Or_Alcohol  \
# 0                  3                          0                 1
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        66 non-null     int64
#  1   Gender                     66 non-null     int64
#  2   Number_Of_Meal             66 non-null     int64
#  3   Avoidance_Screen           66 non-null     int64
#  4   Health_Condition           66 non-null     int64
#  5   Blue_Light_Filter          66 non-null     int64
#  6   Sleeping_Direction         66 non-null     int64
#  7   Naps_During_The_Day        66 non-null     int64
#  8   Physical_Exercise          66 non-null     int64
#  9   Evening_Caffeine_Or_Sugar  66 non-null     int64
#  10  Smoke_Or_Alcohol           66 non-null     int64
#  11  Go_To_Bed_Time             66 non-null     int64
#  12  Wake_Up_Time               66 non-null     int64
# ...

# %%
dataset.describe()
# Out:
#              Age     Gender  Number_Of_Meal  Avoidance_Screen  \
# count  66.000000  66.000000       66.000000         66.000000
# mean    1.121212   0.666667        0.833333          0.606061
# std     0.968983   0.506370        0.869718          0.762159
# min     0.000000   0.000000        0.000000          0.000000
# 25%     1.000000   0.000000        0.000000          0.000000
# 50%     1.000000   1.000000        1.000000          0.000000
# 75%     1.000000   1.000000        1.000000          1.000000
# max     5.000000   2.000000        3.000000          2.000000
#
#        Health_Condition  Blue_Light_Filter  Sleeping_Direction  \
# count         66.000000          66.000000           66.000000
# mean           0.363636           0.378788            1.469697
# std            0.484732           0.488802            0.995678
# min            0.000000           0.000000            0.000000
# 25%            0.000000           0.000000            1.000000
# ...

# %%
plt.figure(figsize=(8, 8))
sns.histplot(data=dataset, kde=True)
plt.title("Histogram of DataFrame")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=dataset, orient='h')
plt.title("Box Plot of DataFrame")
plt.show()

# %%
plt.figure(figsize=(20, 6))
ax = dataset.describe().loc[['mean', 'std', '25%', '50%', '75%', 'max']].plot(kind='bar', legend=False)
plt.title("Bar Plot of Mean, Std, Min, Max")
plt.ylabel("Values")

# Customize x-axis labels
ax.set_xticklabels(['Mean', 'Std', '25%', '50%', '75%', 'Max'], rotation=0)

plt.show()

# %%
dataset.shape
# Out:
# (66, 20)

# %%
dataset.corr()
# Out:
#                                 Age        Gender  Number_Of_Meal  \
# Age                        1.000000  1.149673e-01        0.079107
# Gender                     0.114967  1.000000e+00       -0.023289
# Number_Of_Meal             0.079107 -2.328890e-02        1.000000
# Avoidance_Screen           0.065651  1.727411e-01        0.038682
# Health_Condition           0.035732  6.267832e-02        0.072985
# Blue_Light_Filter          0.031497  3.315007e-01       -0.174913
# Sleeping_Direction        -0.107756 -2.034270e-02        0.091791
# Naps_During_The_Day        0.138082  6.554666e-17        0.132207
# Physical_Exercise          0.030862 -1.948903e-01        0.081950
# Evening_Caffeine_Or_Sugar  0.031513  6.030227e-02        0.087773
# Smoke_Or_Alcohol           0.006836  3.597385e-01        0.062834
# Go_To_Bed_Time             0.138047 -1.059769e-01        0.082601
# Wake_Up_Time               0.127075  2.264749e-01       -0.142550
# ...

# %%
plt.figure(figsize=(18,15))
sns.heatmap(dataset.corr(),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Separate numeric and categorical columns
numeric_columns = dataset.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = dataset.select_dtypes(include=['object']).columns

# Encode categorical columns (you can choose a different encoding method)
encoder = LabelEncoder()
for col in categorical_columns:
    dataset[col] = encoder.fit_transform(dataset[col])

# Separate your features (X) and target variable (y)
X_numeric = dataset[numeric_columns].drop(columns=['Satisfaction'])  # Exclude the target column
y = dataset['Satisfaction']

# Apply feature selection using chi-squared (for classification tasks)
selector = SelectKBest(score_func=chi2, k=5)  # Select the top 5 features

# Fit the selector to your numeric data and transform the features
X_numeric_new = selector.fit_transform(X_numeric, y)

# Get the indices of the selected features
selected_indices = selector.get_support(indices=True)

# Print the names of the selected features
selected_features = X_numeric.columns[selected_indices]
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Gender', 'Number_Of_Meal', 'Physical_Exercise',
#        'Regular_Bedtime_Routine', 'Spend_Time_In_Daylight'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# Splitting the selected numeric features and the target variable (y) into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Print the shapes of the resulting datasets to verify the split
print("Training data shape (X_train, y_train):", X_train.shape, y_train.shape)
print("Testing data shape (X_test, y_test):", X_test.shape, y_test.shape)
# Out:
# Training data shape (X_train, y_train): (52, 5) (52,)
# Testing data shape (X_test, y_test): (14, 5) (14,)

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the Naive Bayes model
model = GaussianNB()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the accuracy
accuracy = np.sum(y_pred == y_test) / len(y_test)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
import seaborn as sns
import matplotlib.pyplot as plt


# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = np.array(pd.crosstab(y_test, y_pred))

# Generate the heatmap
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Naive Bayes Classifier")
plt.show()

# %%
from sklearn.metrics import classification_report

# Create the Naive Bayes model
model = GaussianNB()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00        14
#    macro avg       1.00      1.00      1.00        14
# weighted avg       1.00      1.00      1.00        14

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.naive_bayes import GaussianNB

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the Naive Bayes model
model = GaussianNB()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict_proba(X_test)[:, 1]

# Reshape the predicted values into a 2D array
y_pred = y_pred[:, np.newaxis]

# Create a heatmap of the predicted values
sns.heatmap(y_pred, annot=True, fmt=".3f", cmap="viridis")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted values")
plt.ylabel("Test data instances")

# Add a title to the heatmap
plt.title("Heatmap of predicted values")

# Display the heatmap
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the decision tree classifier
model = DecisionTreeClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)


# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Accuracy:", accuracy)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00        14
#    macro avg       1.00      1.00      1.00        14
# weighted avg       1.00      1.00      1.00        14

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data


# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Generate the confusion matrix graph
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Decision Tree Classifier")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the decision tree model
model = DecisionTreeClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = y_pred[:, np.newaxis]

# Create a heatmap of the predicted values
sns.heatmap(y_pred, annot=True, fmt=".3f", cmap="viridis")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted values")
plt.ylabel("Test data instances")

# Add a title to the heatmap
plt.title("Heatmap of predicted values")

# Display the heatmap
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the model to the training data
knn.fit(X_train, y_train)

# Make predictions on the test data
y_pred = knn.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8571428571428571

# %%
from sklearn.metrics import classification_report

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the model to the training data
knn.fit(X_train, y_train)

# Make predictions on the test data
y_pred = knn.predict(X_test)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         8
#            2       1.00      0.80      0.89         5
#
#     accuracy                           0.86        14
#    macro avg       0.60      0.60      0.59        14
# weighted avg       0.81      0.86      0.83        14

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import matplotlib.pyplot as plt



# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = np.array(pd.crosstab(y_test, y_pred))

# Generate the heatmap
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for KNN Classifier")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the KNN model
model = KNeighborsClassifier(n_neighbors=5)

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = y_pred[:, np.newaxis]

# Create a heatmap of the predicted values
sns.heatmap(y_pred, annot=True, fmt=".3f", cmap="viridis")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted values")
plt.ylabel("Test data instances")

# Add a title to the heatmap
plt.title("Heatmap of predicted values")

# Display the heatmap
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the logistic regression model
model = LogisticRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Print the accuracy
accuracy = np.sum(y_pred == y_test) / len(y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9285714285714286

# %%
from sklearn.metrics import classification_report

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the logistic regression model
model = LogisticRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.89      1.00      0.94         8
#            2       1.00      1.00      1.00         5
#
#     accuracy                           0.93        14
#    macro avg       0.63      0.67      0.65        14
# weighted avg       0.87      0.93      0.89        14

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the logistic regression model
model = LogisticRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred_proba = model.predict_proba(X_test)

# Create a heatmap of the predicted probabilities
sns.heatmap(y_pred_proba, annot=True, fmt=".3f")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted probability of class 1")
plt.ylabel("Actual class")

# Add a title to the heatmap
plt.title("Heatmap of predicted probabilities")

# Display the heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt



# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = np.array(pd.crosstab(y_test, y_pred))

# Generate the heatmap
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Logistic Regression Classifier")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the MAE, MSE, and R^2
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the MAE, MSE, and R^2
print("MAE:", mae)
print("MSE:", mse)
print("R^2:", r2)
# Out:
# MAE: 1.6256837146296934e-16
# MSE: 5.128476309054011e-32
# R^2: 1.0

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create a machine learning model
# ...

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the confusion matrix

# Plot the confusion matrix as a heatmap
sns.heatmap(cm, annot=True, fmt=".0f")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted")
plt.ylabel("Actual")

# Add a title to the heatmap
plt.title("Confusion Matrix of Linear Regression")

# Display the heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data


# Fit the model to the training data
model.fit(X_train, y_train)

# Get the linear regression coefficients
coefs = model.coef_

# Generate a heatmap of the linear regression coefficients
sns.heatmap(coefs.reshape(1, -1), annot=True, fmt=".2f")
plt.xlabel("Features")
plt.ylabel("Linear Regression Coefficients")
plt.title("Heatmap of Linear Regression Coefficients")
plt.show()
